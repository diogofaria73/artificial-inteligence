# %%
import sys
import os
from plotly import graph_objects as go
from plotly import express as px

# Add the src folder to sys.path
sys.path.append(os.path.abspath('../'))

# import source files into
from services import load_data
from services.clean_data_frame import remove_empty_rows
from services.clean_data_frame import one_hot_encoder_columns

# %% [markdown]
# #### Carregamento e Limpeza de Dados

# %%
# Load dataset from the data folder
df = load_data.get_and_clean('raw')

# %%
df_cleaned = remove_empty_rows(df)

# %% [markdown]
# #### Análise Geral dos Dados

# %%
df_cleaned
# Out:
#       marital_status  application_mode  application_order  course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       daytime/evening_attendance  previous_qualification  nacionality  \
# 0                              1                       1            1
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   marital_status                                  4424 non-null   int64
#  1   application_mode                                4424 non-null   int64
#  2   application_order                               4424 non-null   int64
#  3   course                                          4424 non-null   int64
#  4   daytime/evening_attendance                      4424 non-null   int64
#  5   previous_qualification                          4424 non-null   int64
#  6   nacionality                                     4424 non-null   int64
#  7   mother's_qualification                          4424 non-null   int64
#  8   father's_qualification                          4424 non-null   int64
# ...

# %%
df_cleaned.hist(bins=20, figsize=(100, 100));
